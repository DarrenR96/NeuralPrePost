# %%
from library import * 
import torch 

# x = torch.randn(2, 1, 256, 256)
# layer = ConvNextLayer(1, 3, [96, 192, 384, 512])
# x_out = layer(x)

# num_params = sum(param.numel() for param in layer.parameters())
# print(num_params)
# print(x_out.shape)

layer = PostProcessor(1, 6, 3, 384, 3, 768)
x = torch.randn(1, 1, 256, 256)
sc = torch.randn(1, 768)

out = layer(x, sc)
# pytorch_total_params = sum(p.numel() for p in layer.parameters())
# Out:
# 24
# 96
# 384
# torch.Size([1, 1, 256, 256])
# 3299884
